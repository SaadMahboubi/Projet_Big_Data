# %%
from pymongo import MongoClient
import pandas as pd
import numpy as np 
import seaborn as sns
# %matplotlib inline 
import matplotlib.pyplot as plt
import pyspark.sql.functions as F
import pyspark.sql.types as T
import plotly as plt
import plotly.graph_objects as go
import pandas as pd
pd.set_option('display.float_format', lambda x: '%.4f' % x)

client = MongoClient('mongo',27017)

# %% [markdown]
# # Chargement des données mongo

# %%
db = client.database

postCryptoPanic = db.posts
postXRP = db.coursXRP
postBTC = db.coursBTC
postETH = db.coursETH

# %% [markdown]
# # Création de la session spark et connexion à mongo

# %%
from pyspark.sql import SparkSession

db = SparkSession.\
builder.\
appName("myApp").\
config("spark.mongodb.input.uri", "mongodb://mongo:27017/database.*").\
config("spark.mongodb.output.uri", "mongodb://mongo:27017/database.*").\
config("spark.jars.packages", "org.mongodb.spark:mongo-spark-connector_2.12:3.0.0").\
getOrCreate()

# %%
dfXRP = db.read.format("mongo").option("uri","mongodb://mongo:27017/database.coursXRP").load()
dfBTC = db.read.format("mongo").option("uri","mongodb://mongo:27017/database.coursBTC").load()
dfETH = db.read.format("mongo").option("uri","mongodb://mongo:27017/database.coursETH").load()
dfPOST = db.read.format("mongo").option("uri","mongodb://mongo:27017/database.posts").load()

# %% [markdown]
# # Transformation des dataframes

# %% [markdown]
# ## Timestamp, calcul de variation et data cleaning

# %%
new_dfXRP = dfXRP.withColumn('date',F.from_unixtime((F.col('Timestamp')/1000))) 
new_dfXRP = new_dfXRP.withColumn('variation',F.round(((new_dfXRP['close']- new_dfXRP['open'])/ new_dfXRP['open']*100),3))

new_dfBTC = dfBTC.withColumn('date',F.from_unixtime((F.col('Timestamp')/1000))) 
new_dfBTC = new_dfBTC.withColumn('variation',F.round(((new_dfBTC['close']- new_dfBTC['open'])/ new_dfBTC['open']*100),3))

new_dfETH = dfETH.withColumn('date',F.from_unixtime((F.col('Timestamp')/1000))) 
new_dfETH = new_dfETH.withColumn('variation',F.round(((new_dfETH['close']- new_dfETH['open'])/ new_dfETH['open']*100),3))

new_dfPOST = dfPOST.withColumn('date',F.from_unixtime((F.col('published_at'))))

# %%
new_dfXRP = new_dfXRP["date","open","high","low","close","volume", "variation"]
new_dfBTC = new_dfBTC["date","open","high","low","close","volume", "variation"]
new_dfETH = new_dfETH["date","open","high","low","close","volume", "variation"]
new_dfPOST = new_dfPOST["date", "currencies", "title","votes", "url"]

# %%
new_dfXRP.printSchema()
# Out:
# root
#  |-- date: string (nullable = true)
#  |-- open: double (nullable = true)
#  |-- high: double (nullable = true)
#  |-- low: double (nullable = true)
#  |-- close: double (nullable = true)
#  |-- volume: double (nullable = true)
#  |-- variation: double (nullable = true)

# %%
new_dfPOST.show()
# Out:
# +-------------------+--------------------+--------------------+-----+--------------------+
# |               date|          currencies|               title|votes|                 url|
# +-------------------+--------------------+--------------------+-----+--------------------+
# |2021-11-25 11:15:56|[{BTC, Bitcoin, b...|New German Chance...| null|https://cryptopan...|
# |2021-11-25 11:08:31|[{BTC, Bitcoin, b...|Crypto market cap...| good|https://cryptopan...|
# |2021-11-25 10:23:43|[{BTC, Bitcoin, b...|Bitcoin ‘solidifi...| good|https://cryptopan...|
# |2021-11-25 10:10:57|[{BTC, Bitcoin, b...|Bitcoin Puts El S...| good|https://cryptopan...|
# |2021-11-25 10:03:27|[{BTC, Bitcoin, b...|Number of Bitcoin...| good|https://cryptopan...|
# |2021-11-25 09:15:20|[{BTC, Bitcoin, b...|Crypto poses no b...| good|https://cryptopan...|
# |2021-11-25 08:04:54|[{BTC, Bitcoin, b...|Ethereum Poised T...| good|https://cryptopan...|
# |2021-11-25 07:55:06|[{BTC, Bitcoin, b...|Bitcoin Processed...| good|https://cryptopan...|
# |2021-11-25 01:20:00|[{ETH, Ethereum, ...|Crypto.com Coin: ...| good|https://cryptopan...|
# |2021-11-24 22:20:41|[{BTC, Bitcoin, b...|Payments Giant St...| good|https://cryptopan...|
# |2021-11-24 22:08:17|[{XRP, XRP, rippl...|Ripple co-founder...| good|https://cryptopan...|
# |2021-11-24 21:17:09|[{BTC, Bitcoin, b...|Kazakhstan might ...| good|https://cryptopan...|
# |2021-11-24 20:00:00|[{BTC, Bitcoin, b...|Morgan Stanley in...| good|https://cryptopan...|
# |2021-11-24 17:05:52|[{BTC, Bitcoin, b...|Morgan Stanley Fu...| good|https://cryptopan...|
# |2021-11-24 16:07:19|[{ETH, Ethereum, ...|Decentraland Cros...| good|https://cryptopan...|
# +-------------------+--------------------+--------------------+-----+--------------------+

# %% [markdown]
# ### Exemples sur XRP

# %%
new_dfXRP.show()
# Out:
# +-------------------+------+------+------+------+---------+---------+
# |               date|  open|  high|   low| close|   volume|variation|
# +-------------------+------+------+------+------+---------+---------+
# |2021-11-22 04:25:00|1.0394|1.0408|1.0372|1.0402| 834920.0|     0.08|
# |2021-11-22 04:30:00|1.0402|1.0402|1.0359|1.0373| 600364.0|    -0.28|
# |2021-11-22 04:35:00|1.0373|1.0395|1.0356| 1.039| 604846.0|     0.16|
# |2021-11-22 04:40:00| 1.039|  1.04| 1.036|1.0362| 788089.0|    -0.27|
# |2021-11-22 04:45:00|1.0362|1.0388|1.0357|1.0388| 675312.0|     0.25|
# |2021-11-22 04:50:00|1.0388|1.0392|1.0327|1.0339| 914497.0|    -0.47|
# |2021-11-22 04:55:00|1.0336|1.0361| 1.032|1.0338|1050190.0|     0.02|
# |2021-11-22 05:00:00|1.0337|1.0351|1.0292|1.0306|1464764.0|     -0.3|
# |2021-11-22 05:05:00|1.0305|1.0319|1.0262|1.0282|1629401.0|    -0.22|
# |2021-11-22 05:10:00|1.0282|1.0312|1.0251| 1.031|1359418.0|     0.27|
# |2021-11-22 05:15:00| 1.031|1.0329|  1.03|1.0329| 780156.0|     0.18|
# |2021-11-22 05:20:00|1.0329| 1.039|1.0318|1.0372|2409701.0|     0.42|
# |2021-11-22 05:25:00|1.0372|1.0382|1.0337|1.0343|1235675.0|    -0.28|
# |2021-11-22 05:30:00|1.0345|1.0378|1.0342|1.0367|1137503.0|     0.21|
# |2021-11-22 05:35:00|1.0367|1.0377|1.0359|1.0374| 487483.0|     0.07|
# |2021-11-22 05:40:00|1.0374|1.0394| 1.037|1.0371| 928851.0|    -0.03|
# |2021-11-22 05:45:00|1.0372|1.0413|1.0364|1.0408|1006292.0|     0.35|
# |2021-11-22 05:50:00|1.0409|1.0418|1.0392|1.0414|1128688.0|     0.05|
# |2021-11-22 05:55:00|1.0414|1.0429|1.0396|1.0429| 779694.0|     0.14|
# |2021-11-22 06:00:00|1.0429|1.0431|1.0394|1.0405| 816913.0|    -0.23|
# +-------------------+------+------+------+------+---------+---------+
# only showing top 20 rows

# %% [markdown]
# # Exemples de filtres

# %%
new_dfXRP.where(dfXRP['volume']>1000000.0).show()
# Out:
# +-------------------+------+------+------+------+---------+---------+
# |               date|  open|  high|   low| close|   volume|variation|
# +-------------------+------+------+------+------+---------+---------+
# |2021-11-22 04:55:00|1.0336|1.0361| 1.032|1.0338|1050190.0|     0.02|
# |2021-11-22 05:00:00|1.0337|1.0351|1.0292|1.0306|1464764.0|     -0.3|
# |2021-11-22 05:05:00|1.0305|1.0319|1.0262|1.0282|1629401.0|    -0.22|
# |2021-11-22 05:10:00|1.0282|1.0312|1.0251| 1.031|1359418.0|     0.27|
# |2021-11-22 05:20:00|1.0329| 1.039|1.0318|1.0372|2409701.0|     0.42|
# |2021-11-22 05:25:00|1.0372|1.0382|1.0337|1.0343|1235675.0|    -0.28|
# |2021-11-22 05:30:00|1.0345|1.0378|1.0342|1.0367|1137503.0|     0.21|
# |2021-11-22 05:45:00|1.0372|1.0413|1.0364|1.0408|1006292.0|     0.35|
# |2021-11-22 05:50:00|1.0409|1.0418|1.0392|1.0414|1128688.0|     0.05|
# |2021-11-22 06:55:00|1.0409|1.0427|1.0405|1.0414|1051802.0|     0.05|
# |2021-11-22 07:00:00|1.0414|1.0491|1.0411|1.0487|2217928.0|      0.7|
# |2021-11-22 07:05:00|1.0486|1.0495|1.0461|1.0472|1193199.0|    -0.13|
# |2021-11-22 07:25:00|1.0452|1.0495| 1.045|1.0493|1053657.0|     0.39|
# |2021-11-22 08:30:00|1.0464|1.0467|1.0429|1.0438|1566116.0|    -0.25|
# |2021-11-22 09:10:00|1.0509|1.0539|1.0508|1.0525|1224496.0|     0.15|
# |2021-11-22 09:55:00| 1.046|1.0466|1.0407|1.0409|2012848.0|    -0.49|
# |2021-11-22 10:00:00|1.0409|1.0434|1.0399|1.0408|1084891.0|    -0.01|
# |2021-11-22 10:05:00|1.0407|1.0413|1.0363|1.0412|1420096.0|     0.05|
# |2021-11-22 10:15:00|1.0439|1.0463|1.0422|1.0426|1290594.0|    -0.12|
# |2021-11-22 11:05:00|1.0472|  1.05|1.0467|  1.05|1097454.0|     0.27|
# +-------------------+------+------+------+------+---------+---------+
# only showing top 20 rows

# %%
new_dfXRP.summary("min","max").show()
# Out:
# +-------+-------------------+------+------+------+------+---------+---------+
# |summary|               date|  open|  high|   low| close|   volume|variation|
# +-------+-------------------+------+------+------+------+---------+---------+
# |    min|2021-11-22 04:25:00|1.0104|1.0139|1.0068|1.0103|  20345.0|    -0.98|
# |    max|2021-11-25 15:45:00|1.0716|1.0735|  1.07|1.0716|9559760.0|     1.16|
# +-------+-------------------+------+------+------+------+---------+---------+

# %%
new_dfXRP.where(new_dfXRP['date'].startswith("2021-11-22")).show()
# Out:
# +-------------------+------+------+------+------+---------+---------+
# |               date|  open|  high|   low| close|   volume|variation|
# +-------------------+------+------+------+------+---------+---------+
# |2021-11-22 04:25:00|1.0394|1.0408|1.0372|1.0402| 834920.0|     0.08|
# |2021-11-22 04:30:00|1.0402|1.0402|1.0359|1.0373| 600364.0|    -0.28|
# |2021-11-22 04:35:00|1.0373|1.0395|1.0356| 1.039| 604846.0|     0.16|
# |2021-11-22 04:40:00| 1.039|  1.04| 1.036|1.0362| 788089.0|    -0.27|
# |2021-11-22 04:45:00|1.0362|1.0388|1.0357|1.0388| 675312.0|     0.25|
# |2021-11-22 04:50:00|1.0388|1.0392|1.0327|1.0339| 914497.0|    -0.47|
# |2021-11-22 04:55:00|1.0336|1.0361| 1.032|1.0338|1050190.0|     0.02|
# |2021-11-22 05:00:00|1.0337|1.0351|1.0292|1.0306|1464764.0|     -0.3|
# |2021-11-22 05:05:00|1.0305|1.0319|1.0262|1.0282|1629401.0|    -0.22|
# |2021-11-22 05:10:00|1.0282|1.0312|1.0251| 1.031|1359418.0|     0.27|
# |2021-11-22 05:15:00| 1.031|1.0329|  1.03|1.0329| 780156.0|     0.18|
# |2021-11-22 05:20:00|1.0329| 1.039|1.0318|1.0372|2409701.0|     0.42|
# |2021-11-22 05:25:00|1.0372|1.0382|1.0337|1.0343|1235675.0|    -0.28|
# |2021-11-22 05:30:00|1.0345|1.0378|1.0342|1.0367|1137503.0|     0.21|
# |2021-11-22 05:35:00|1.0367|1.0377|1.0359|1.0374| 487483.0|     0.07|
# |2021-11-22 05:40:00|1.0374|1.0394| 1.037|1.0371| 928851.0|    -0.03|
# |2021-11-22 05:45:00|1.0372|1.0413|1.0364|1.0408|1006292.0|     0.35|
# |2021-11-22 05:50:00|1.0409|1.0418|1.0392|1.0414|1128688.0|     0.05|
# |2021-11-22 05:55:00|1.0414|1.0429|1.0396|1.0429| 779694.0|     0.14|
# |2021-11-22 06:00:00|1.0429|1.0431|1.0394|1.0405| 816913.0|    -0.23|
# +-------------------+------+------+------+------+---------+---------+
# only showing top 20 rows

# %% [markdown]
# #### Statistique déscriptive des cloture et volume sur une période définie

# %%
XRP_filtered_period = new_dfXRP.filter(F.col("date").between('2021-11-22 08:00:00', '2021-11-22 09:00:00'))
XRP_filtered_period.describe('close','volume').show()
# Out:
# +-------+--------------------+------------------+
# |summary|               close|            volume|
# +-------+--------------------+------------------+
# |  count|                  26|                26|
# |   mean|  1.0447846153846156| 672391.3846153846|
# | stddev|0.001112723616246...|309335.31857802166|
# |    min|               1.043|          405122.0|
# |    max|              1.0466|         1566116.0|
# +-------+--------------------+------------------+

# %% [markdown]
# # DATAVIZ

# %%
dfPOSTpanda = new_dfPOST.toPandas()
dfBTCpanda = new_dfBTC.toPandas()
dfXRPpanda = new_dfXRP.toPandas()
dfETHpanda = new_dfETH.toPandas()

# %%
dfPOSTpanda
# Out:
#                    date                                         currencies  \
# 0   2021-11-25 11:15:56  [(BTC, Bitcoin, bitcoin, https://cryptopanic.c...
# 1   2021-11-25 11:08:31  [(BTC, Bitcoin, bitcoin, https://cryptopanic.c...
# 2   2021-11-25 10:23:43  [(BTC, Bitcoin, bitcoin, https://cryptopanic.c...
# 3   2021-11-25 10:10:57  [(BTC, Bitcoin, bitcoin, https://cryptopanic.c...
# 4   2021-11-25 10:03:27  [(BTC, Bitcoin, bitcoin, https://cryptopanic.c...
# 5   2021-11-25 09:15:20  [(BTC, Bitcoin, bitcoin, https://cryptopanic.c...
# 6   2021-11-25 08:04:54  [(BTC, Bitcoin, bitcoin, https://cryptopanic.c...
# 7   2021-11-25 07:55:06  [(BTC, Bitcoin, bitcoin, https://cryptopanic.c...
# 8   2021-11-25 01:20:00  [(ETH, Ethereum, ethereum, https://cryptopanic...
# 9   2021-11-24 22:20:41  [(BTC, Bitcoin, bitcoin, https://cryptopanic.c...
# 10  2021-11-24 22:08:17  [(XRP, XRP, ripple, https://cryptopanic.com/ne...
# 11  2021-11-24 21:17:09  [(BTC, Bitcoin, bitcoin, https://cryptopanic.c...
# 12  2021-11-24 20:00:00  [(BTC, Bitcoin, bitcoin, https://cryptopanic.c...
# 13  2021-11-24 17:05:52  [(BTC, Bitcoin, bitcoin, https://cryptopanic.c...
# 14  2021-11-24 16:07:19  [(ETH, Ethereum, ethereum, https://cryptopanic...
#
#                                                 title votes  \
# 0   New German Chancellor Olaf Scholz Made A Serio...  None
# 1   Crypto market cap rebounds as Metaverse tokens...  good
# 2   Bitcoin ‘solidifies’ support at $58K as BTC pr...  good
# 3   Bitcoin Puts El Salvador On The Map As Tourism...  good
# 4   Number of Bitcoin wallets with non-zero balanc...  good
# 5   Crypto poses no big risk to economy so far, Ba...  good
# 6   Ethereum Poised To Dramatically Outperform Bit...  good
# 7   Bitcoin Processed 62% More Transactions Than P...  good
# 8   Crypto.com Coin: Crypto Analytics Startup Issu...  good
# 9   Payments Giant Stripe Confirms It May Restart ...  good
# 10  Ripple co-founder Jed McCaleb hasn’t sold XRP ...  good
# 11  Kazakhstan might build nuclear plant to keep B...  good
# 12  Morgan Stanley increased exposure to Bitcoin, ...  good
# 13  Morgan Stanley Funds Add More Than 2.64M Share...  good
# 14  Decentraland Crosses 10% of Facebook’s Budget ...  good
#
#                                                   url
# 0   https://cryptopanic.com/news/13461232/New-Germ...
# 1   https://cryptopanic.com/news/13461209/Crypto-m...
# 2   https://cryptopanic.com/news/13461087/Bitcoin-...
# 3   https://cryptopanic.com/news/13461066/Bitcoin-...
# 4   https://cryptopanic.com/news/13461039/Number-o...
# 5   https://cryptopanic.com/news/13460875/Crypto-p...
# 6   https://cryptopanic.com/news/13458994/Ethereum...
# 7   https://cryptopanic.com/news/13458759/Bitcoin-...
# 8   https://cryptopanic.com/news/13451945/Cryptoco...
# 9   https://cryptopanic.com/news/13451486/Payments...
# 10  https://cryptopanic.com/news/13451432/Ripple-c...
# 11  https://cryptopanic.com/news/13451287/Kazakhst...
# 12  https://cryptopanic.com/news/13450989/Morgan-S...
# 13  https://cryptopanic.com/news/13450245/Morgan-S...
# 14  https://cryptopanic.com/news/13450019/Decentra...

# %% [markdown]
# ## Filtre sur post Crypto Panic

# %% [markdown]
# ## Récupération du cours de la crypto avant et après la parution d'un post

# %%
from pyspark.sql.functions import from_utc_timestamp

#obtention de la dataframe et du cours de la crypto corréspodant au post CryptoPanic à partir de sa création 
#(après et avant)

for row in dfPOSTpanda.itertuples():
    currencies = row[2]
    titre = row[3]
    dataOfPublication = row[1]
    for currencie in currencies:
        if currencie["code"] == "XRP":
            print(dataOfPublication)
            print(titre)
            afterPublicationXRP = new_dfXRP.where(new_dfXRP['date']>row[1])
            beforePublicationXRP = new_dfXRP.where(new_dfXRP['date']<row[1])
# Out:
# 2021-11-24 22:08:17
# Ripple co-founder Jed McCaleb hasn’t sold XRP in 3 months, still holds $730M

# %% [markdown]
# ## Impact du post du post sur le cours de la crypto

# %%
beforePublicationXRP.describe("volume","close").show()
# Out:
# +-------+------------------+-------------------+
# |summary|            volume|              close|
# +-------+------------------+-------------------+
# |  count|               423|                423|
# |   mean|1144451.1749408983|  1.037771631205674|
# | stddev| 651087.7989710014|0.00912768036001847|
# |    min|           20345.0|             1.0227|
# |    max|         5684606.0|             1.0571|
# +-------+------------------+-------------------+

# %%
afterPublicationXRP.describe("volume","close").show()
# Out:
# +-------+------------------+--------------------+
# |summary|            volume|               close|
# +-------+------------------+--------------------+
# |  count|              1577|                1577|
# |   mean|1145260.8560558022|  1.0422078630310727|
# | stddev| 779425.5033600159|0.011288860196204576|
# |    min|          247433.0|              1.0103|
# |    max|         9559760.0|              1.0716|
# +-------+------------------+--------------------+

# %% [markdown]
# ## Visualisation sur Pandas et plotly

# %%
beforePublicationXRPpd = beforePublicationXRP.toPandas()
afterPublicationXRPpd = afterPublicationXRP.toPandas()

# %%
#realisation d'un graph interactif
figBefore = go.Figure(data=[go.Candlestick(x=beforePublicationXRPpd['date'],open=beforePublicationXRPpd['open'], high=beforePublicationXRPpd['high'], low=beforePublicationXRPpd['low'], close=beforePublicationXRPpd['close'])])

#fig.update_layout(xaxis_rangeslider_visible=False)
figBefore.show()
# Out:
# <div>                            <div id="b7ae7b8d-3e90-4627-9333-c7a2d7ca638c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b7ae7b8d-3e90-4627-9333-c7a2d7ca638c")) {                    Plotly.newPlot(                        "b7ae7b8d-3e90-4627-9333-c7a2d7ca638c",                        [{"close":[1.0402,1.0373,1.039,1.0362,1.0388,1.0339,1.0338,1.0306,1.0282,1.031,1.0329,1.0372,1.0343,1.0367,1.0374,1.0371,1.0408,1.0414,1.0429,1.0405,1.0408,1.0406,1.04,1.0384,1.0375,1.0408,1.0396,1.0405,1.0393,1.0408,1.0414,1.0487,1.0472,1.0452,1.0452,1.0452,1.0493,1.0481,1.0464,1.046,1.0452,1.0449,1.0423,1.0452,1.044,1.0437,1.0437,1.045,1.0464,1.0438,1.0459,1.0454,1.043,1.0453,1.0442,1.0466,1.051,1.0525,1.0512,1.0491,1.0495,1.05,1.0481,1.0479,1.0485,1.046,1.0409,1.0408,1.0412,1.044,1.0426,1.0441,1.043,1.0446,1.043,1.0438,1.0442,1.0443,1.0479,1.0472,1.05,1.05,1.051,1.0492,1.05,1.0478,1.0493,1.0494,1.0509,1.0478,1.0473,1.0473,1.0464,1.0447,1.047,1.0467,1.0513,1.054,1.0502,1.0523,1.0475,1.0505,1.0504,1.0513,1.0411,1.0407,1.0386,1.0446,1.051,1.0566,1.061,1.0651,1.0599,1.0603,1.0624,1.0652,1.0652,1.0643,1.0603,1.0577,1.057,1.0582,1.057,1.0592,1.0579,1.0562,1.0572,1.0602,1.0562,1.0578,1.0574,1.0587,1.0573,1.0566,1.0566,1.056,1.0571,1.0564,1.0564,1.0553,1.055,1.0528,1.0546,1.0538,1.0518,1.0525,1.0533,1.0528,1.0519,1.052,1.0523,1.0511,1.0513,1.0516,1.0516,1.0499,1.0495,1.0474,1.0466,1.0467,1.048,1.0468,1.0483,1.0474,1.0471,1.0465,1.0475,1.0454,1.0446,1.0425,1.0409,1.0392,1.041,1.0408,1.0381,1.0429,1.0415,1.042,1.0379,1.0385,1.0332,1.034,1.0307,1.0326,1.0315,1.0287,1.0305,1.0314,1.035,1.0338,1.0362,1.0332,1.0332,1.0348,1.0355,1.0346,1.0331,1.0316,1.0314,1.0336,1.0295,1.0297,1.0291,1.0304,1.0307,1.0351,1.0364,1.0358,1.0343,1.0361,1.0365,1.0384,1.0385,1.0377,1.0342,1.0366,1.0364,1.0362,1.0394,1.0409,1.0428,1.044,1.0449,1.0403,1.0397,1.0406,1.0397,1.0376,1.0367,1.0365,1.035,1.0344,1.0355,1.0365,1.0354,1.0366,1.0332,1.0316,1.0359,1.0426,1.0466,1.043,1.0441,1.0417,1.0425,1.0446,1.0439,1.0455,1.0452,1.043,1.0407,1.0439,1.0449,1.0426,1.0419,1.0423,1.0437,1.0459,1.0448,1.0465,1.0454,1.0432,1.0447,1.045,1.0467,1.0465,1.0466,1.0456,1.0457,1.0474,1.0516,1.0527,1.0543,1.0545,1.0545,1.0527,1.0528,1.0536,1.0528,1.0532,1.0553,1.0536,1.0544,1.0513,1.0511,1.0501,1.0517,1.0515,1.0522,1.0514,1.0513,1.0506,1.0517,1.0497,1.0502,1.0479,1.0489,1.0454,1.0453,1.0453,1.0441,1.0458,1.0462,1.0436,1.0443,1.0442,1.0451,1.0445,1.0462,1.0446,1.0461,1.0444,1.0418,1.0425,1.0427,1.0416,1.0416,1.0414,1.0413,1.0401,1.0383,1.0372,1.0351,1.0343,1.0353,1.0353,1.0368,1.0358,1.0364,1.0377,1.0359,1.037,1.036,1.034,1.0333,1.0319,1.0323,1.0347,1.0334,1.0349,1.0366,1.0392,1.0397,1.042,1.0415,1.0386,1.038,1.0367,1.0361,1.0281,1.0309,1.0427,1.0431,1.0378,1.0365,1.031,1.0385,1.0505,1.0568,1.0574,1.0538,1.0509,1.0516,1.0565,1.0507,1.0476,1.0442,1.0403,1.0406,1.0417,1.0388,1.0378,1.0386,1.0413,1.0385,1.0352,1.0348,1.0365,1.0351,1.0382,1.0384,1.0386,1.0359,1.0389,1.0379,1.0322,1.0336,1.0348,1.0343,1.0363,1.036,1.0393,1.042,1.0409,1.0439,1.0433,1.0471,1.0449,1.0467,1.0446,1.0435,1.0435,1.0437,1.0432,1.0463,1.0475,1.0458,1.0483,1.0492,1.0465,1.0458,1.0468,1.0488,1.054,1.0549,1.0524,1.0534,1.0515,1.0504,1.0508,1.0506,1.0516,1.0505,1.049,1.0487,1.0474,1.0462,1.0497,1.049,1.0508,1.0524,1.0522,1.0509,1.0492,1.0492,1.048,1.0486,1.0514,1.0512,1.0504,1.0487,1.0478,1.0485,1.0498,1.0491,1.0487,1.0489,1.048,1.0495,1.0465,1.0452,1.0446,1.0445,1.0439,1.0426,1.0423,1.0429,1.0429,1.0427,1.0446,1.045,1.0464,1.0451,1.0452,1.0471,1.0463,1.045,1.0465,1.0477,1.0483,1.0505,1.0542,1.0531,1.053,1.0539,1.0548,1.0532,1.0561,1.0532,1.0531,1.0535,1.0535,1.0545,1.0557,1.055,1.0565,1.0584,1.0569,1.0582,1.0569,1.0579,1.057,1.0586,1.0562,1.0536,1.0538,1.0539,1.0543,1.0543,1.0561,1.055,1.0551,1.059 ...

# %%
#realisation d'un graph interactif
figAfter = go.Figure(data=[go.Candlestick(x=afterPublicationXRPpd['date'],open=afterPublicationXRPpd['open'], high=afterPublicationXRPpd['high'], low=afterPublicationXRPpd['low'], close=afterPublicationXRPpd['close'])])

#fig.update_layout(xaxis_rangeslider_visible=False)
figAfter.show()
